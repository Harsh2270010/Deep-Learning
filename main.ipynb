# %%
import numpy as np
import pandas as pd 
import matplotlib as plt 
import seaborn as sns

# %%
data = pd.read_csv("cust_satisfaction.csv")
data.head(8)
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
# 5  Female     Loyal Customer  Personal Travel       Eco
# 6    Male     Loyal Customer  Personal Travel       Eco
# 7  Female     Loyal Customer  Business travel  Business
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
# 3  neutral or dissatisfied   25              562                       2
# 4                satisfied   61              214                       3
# 5  neutral or dissatisfied   26             1180                       1
# 6  neutral or dissatisfied   47             1276                       2
# 7                satisfied   52             2035                       5
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# 2                 4            5                           0
# 3                 3            2                          11
# 4                 4            3                           0
# 5                 4            1                           0
# 6                 4            2                           9
# 7                 5            4                           4
#
#    Arrival Delay in Minutes
# 0                      18.0
# 1                       6.0
# 2                       0.0
# 3                       9.0
# 4                       0.0
# 5                       0.0
# 6                      23.0
# 7                       0.0

# %%
data.isnull().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data[data.duplicated()]
# Out:
#         Gender      Customer Type   Type of Travel     Class satisfaction  \
# 2741      Male     Loyal Customer  Business travel  Business    satisfied
# 5228      Male  disloyal Customer  Business travel       Eco    satisfied
# 6278    Female  disloyal Customer  Business travel  Business    satisfied
# 7330      Male     Loyal Customer  Business travel  Business    satisfied
# 8405      Male     Loyal Customer  Business travel  Business    satisfied
# ...        ...                ...              ...       ...          ...
# 102110    Male     Loyal Customer  Business travel  Business    satisfied
# 102327    Male     Loyal Customer  Business travel  Business    satisfied
# 102679  Female     Loyal Customer  Business travel  Business    satisfied
# 102801    Male     Loyal Customer  Business travel  Business    satisfied
# 103627    Male     Loyal Customer  Business travel  Business    satisfied
#
#         Age  Flight Distance  Inflight entertainment  Baggage handling  \
# 2741     56             1535                       5                 5
# 5228     20              861                       2                 5
# 6278     21              448                       2                 5
# 7330     49              258                       4                 4
# 8405     53             2149                       4                 4
# ...     ...              ...                     ...               ...
# 102110   45             1389                       5                 5
# 102327   56              444                       5                 5
# 102679   44              862                       5                 5
# 102801   48             3354                       4                 4
# 103627   46              945                       4                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 2741              3                           0                       0.0
# 5228              2                           0                       0.0
# 6278              2                           0                       0.0
# 7330              4                           0                       0.0
# 8405              3                           0                       0.0
# ...             ...                         ...                       ...
# 102110            3                           0                       0.0
# 102327            5                           1                       0.0
# 102679            5                           0                       0.0
# 102801            4                           0                       0.0
# 103627            4                           0                       0.0
#
# [172 rows x 12 columns]

# %%
data.drop_duplicates(inplace=True)
print(data.duplicated().sum())
# Out:
# 0

# %%
data["Class"].value_counts()
# Out:
# Class
# Business    49423
# Eco         46532
# Eco Plus     7467
# Name: count, dtype: int64

# %%
data["Type of Travel"].value_counts()
# Out:
# Type of Travel
# Business travel    71331
# Personal Travel    32091
# Name: count, dtype: int64

# %%
data["satisfaction"].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    58636
# satisfied                  44786
# Name: count, dtype: int64

# %%
data["Customer Type"].value_counts()
# Out:
# Customer Type
# Loyal Customer       84517
# disloyal Customer    18905
# Name: count, dtype: int64

# %%
data["Gender"]=data["Gender"].map({"Male":1,"Female":0})
data["Customer Type"]=data["Customer Type"].map({"Loyal Customer":1,"disloyal Customer":0})
data["Type of Travel"]=data["Type of Travel"].map({"Personal Travel":0,"Business travel":1})
data["Class"]=data["Class"].map({"Business":1,"Eco":2,"Eco Plus":3})
data["satisfaction"]=data["satisfaction"].map({"neutral or dissatisfied":0,"satisfied":1})

# %%
data['Class'].value_counts()
# Out:
# Class
# 1    49423
# 2    46532
# 3     7467
# Name: count, dtype: int64

# %%
data['Type of Travel'].value_counts()
# Out:
# Type of Travel
# 1    71331
# 0    32091
# Name: count, dtype: int64

# %%
data['satisfaction'].value_counts()
# Out:
# satisfaction
# 0    58636
# 1    44786
# Name: count, dtype: int64

# %%
data['Customer Type'].value_counts()
# Out:
# Customer Type
# 1    84517
# 0    18905
# Name: count, dtype: int64

# %%
data.head()
# Out:
#    Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0       1              1               0      3             0   13
# 1       1              0               1      1             0   25
# 2       0              1               1      1             1   26
# 3       0              1               1      1             0   25
# 4       1              1               1      1             1   61
#
#    Flight Distance  Inflight entertainment  Baggage handling  Cleanliness  \
# 0              460                       5                 4            5
# 1              235                       1                 3            1
# 2             1142                       5                 4            5
# 3              562                       2                 3            2
# 4              214                       3                 4            3
#
#    Departure Delay in Minutes  Arrival Delay in Minutes
# 0                          25                      18.0
# 1                           1                       6.0
# 2                           0                       0.0
# 3                          11                       9.0
# 4                           0                       0.0

# %%
loyal_customer=data[data["Customer Type"]==1].loc[0:20000]
disloyal_customer=data[data["Customer Type"]==0]

# %%
balance_df=pd.concat([loyal_customer,disloyal_customer],axis=0)
balance_df.head()
# Out:
#    Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0       1              1               0      3             0   13
# 2       0              1               1      1             1   26
# 3       0              1               1      1             0   25
# 4       1              1               1      1             1   61
# 5       0              1               0      2             0   26
#
#    Flight Distance  Inflight entertainment  Baggage handling  Cleanliness  \
# 0              460                       5                 4            5
# 2             1142                       5                 4            5
# 3              562                       2                 3            2
# 4              214                       3                 4            3
# 5             1180                       1                 4            1
#
#    Departure Delay in Minutes  Arrival Delay in Minutes
# 0                          25                      18.0
# 2                           0                       0.0
# 3                          11                       9.0
# 4                           0                       0.0
# 5                           0                       0.0

# %%
balance_df.isnull().sum()
# Out:
# Gender                        0
# Customer Type                 0
# Type of Travel                0
# Class                         0
# satisfaction                  0
# Age                           0
# Flight Distance               0
# Inflight entertainment        0
# Baggage handling              0
# Cleanliness                   0
# Departure Delay in Minutes    0
# Arrival Delay in Minutes      0
# dtype: int64

# %%
x=balance_df.drop("Customer Type",axis=1)
y=balance_df[["Customer Type"]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train_scaled=sc.fit_transform(x_train)
x_test_scaled=sc.transform(x_test)

# %%
x_train_scaled.shape
# Out:
# (28191, 11)

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense,Dropout

#defining the ann model
model=Sequential()

#input layer
model.add(Dense(68,activation="relu",input_dim=x_train_scaled.shape[1]))
model.add(Dropout(0.3))

#hidden layer
model.add(Dense(32,activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(24,activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(22,activation="relu"))
model.add(Dropout(0.3))

#output layer
model.add(Dense(1,activation="sigmoid"))

#compile our model
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])
model.summary()
# Out:
# C:\Users\verma\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                 │ (None, 68)             │           816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 68)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │         2,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 24)             │           792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 24)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 22)             │           550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 22)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            23 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,389 (17.14 KB)
#  Trainable params: 4,389 (17.14 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
##  Param=(input feature+1)* no. of neurons at layers
# ex=

# %%
history = model.fit(
    x_train_scaled,y_train,
    epochs = 50,
    batch_size=32,
    validation_data=(x_test_scaled,y_test)
)
# Out:
# Epoch 1/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7783 - loss: 0.4634 - val_accuracy: 0.9022 - val_loss: 0.2590
# Epoch 2/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8910 - loss: 0.3042 - val_accuracy: 0.9061 - val_loss: 0.2419
# Epoch 3/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9006 - loss: 0.2816 - val_accuracy: 0.9117 - val_loss: 0.2359
# Epoch 4/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9020 - loss: 0.2661 - val_accuracy: 0.9108 - val_loss: 0.2274
# Epoch 5/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9049 - loss: 0.2611 - val_accuracy: 0.9110 - val_loss: 0.2270
# Epoch 6/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9099 - loss: 0.2510 - val_accuracy: 0.9154 - val_loss: 0.2213
# Epoch 7/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9112 - loss: 0.2484 - val_accuracy: 0.9143 - val_loss: 0.2152
# Epoch 8/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9124 - loss: 0.2444 - val_accuracy: 0.9177 - val_loss: 0.2134
# Epoch 9/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9109 - loss: 0.2473 - val_accuracy: 0.9176 - val_loss: 0.2106
# Epoch 10/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9121 - loss: 0.2431 - val_accuracy: 0.9184 - val_loss: 0.2084
# Epoch 11/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9143 - loss: 0.2376 - val_accuracy: 0.9170 - val_loss: 0.2093
# Epoch 12/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9159 - loss: 0.2340 - val_accuracy: 0.9187 - val_loss: 0.2095
# Epoch 13/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9189 - loss: 0.2322 - val_accuracy: 0.9214 - val_loss: 0.2059
# Epoch 14/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9160 - loss: 0.2306 - val_accuracy: 0.9194 - val_loss: 0.2056
# Epoch 15/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9164 - loss: 0.2279 - val_accuracy: 0.9207 - val_loss: 0.2044
# Epoch 16/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9145 - loss: 0.2351 - val_accuracy: 0.9231 - val_loss: 0.2035
# Epoch 17/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9213 - loss: 0.2209 - val_accuracy: 0.9204 - val_loss: 0.2045
# Epoch 18/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9129 - loss: 0.2327 - val_accuracy: 0.9224 - val_loss: 0.2026
# Epoch 19/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9140 - loss: 0.2312 - val_accuracy: 0.9242 - val_loss: 0.2006
# Epoch 20/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9161 - loss: 0.2305 - val_accuracy: 0.9238 - val_loss: 0.2008
# Epoch 21/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9163 - loss: 0.2300 - val_accuracy: 0.9207 - val_loss: 0.2021
# Epoch 22/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9150 - loss: 0.2297 - val_accuracy: 0.9215 - val_loss: 0.2018
# Epoch 23/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9190 - loss: 0.2229 - val_accuracy: 0.9224 - val_loss: 0.2043
# Epoch 24/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9161 - loss: 0.2248 - val_accuracy: 0.9225 - val_loss: 0.2026
# Epoch 25/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9187 - loss: 0.2246 - val_accuracy: 0.9247 - val_loss: 0.2008
# Epoch 26/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9182 - loss: 0.2208 - val_accuracy: 0.9248 - val_loss: 0.1992
# Epoch 27/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9218 - loss: 0.2175 - val_accuracy: 0.9245 - val_loss: 0.1990
# Epoch 28/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9196 - loss: 0.2189 - val_accuracy: 0.9251 - val_loss: 0.1981
# Epoch 29/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9177 - loss: 0.2221 - val_accuracy: 0.9255 - val_loss: 0.1977
# Epoch 30/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9186 - loss: 0.2182 - val_accuracy: 0.9242 - val_loss: 0.2014
# Epoch 31/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9177 - loss: 0.2183 - val_accuracy: 0.9221 - val_loss: 0.2010
# Epoch 32/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9192 - loss: 0.2215 - val_accuracy: 0.9235 - val_loss: 0.2010
# Epoch 33/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9176 - loss: 0.2184 - val_accuracy: 0.9258 - val_loss: 0.1974
# Epoch 34/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9207 - loss: 0.2165 - val_accuracy: 0.9224 - val_loss: 0.2016
# Epoch 35/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9217 - loss: 0.2117 - val_accuracy: 0.9231 - val_loss: 0.1978
# Epoch 36/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9186 - loss: 0.2180 - val_accuracy: 0.9249 - val_loss: 0.1961
# Epoch 37/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9193 - loss: 0.2219 - val_accuracy: 0.9238 - val_loss: 0.1958
# Epoch 38/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9221 - loss: 0.2158 - val_accuracy: 0.9228 - val_loss: 0.1986
# Epoch 39/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9192 - loss: 0.2206 - val_accuracy: 0.9230 - val_loss: 0.1982
# Epoch 40/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9210 - loss: 0.2137 - val_accuracy: 0.9238 - val_loss: 0.1961
# Epoch 41/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9171 - loss: 0.2249 - val_accuracy: 0.9232 - val_loss: 0.1978
# Epoch 42/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9214 - loss: 0.2184 - val_accuracy: 0.9244 - val_loss: 0.1979
# Epoch 43/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9217 - loss: 0.2146 - val_accuracy: 0.9245 - val_loss: 0.1970
# Epoch 44/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9229 - loss: 0.2154 - val_accuracy: 0.9248 - val_loss: 0.1996
# Epoch 45/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9194 - loss: 0.2158 - val_accuracy: 0.9248 - val_loss: 0.1957
# Epoch 46/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9190 - loss: 0.2140 - val_accuracy: 0.9269 - val_loss: 0.1945
# Epoch 47/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9217 - loss: 0.2110 - val_accuracy: 0.9207 - val_loss: 0.1979
# Epoch 48/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9228 - loss: 0.2071 - val_accuracy: 0.9248 - val_loss: 0.1993
# Epoch 49/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9185 - loss: 0.2142 - val_accuracy: 0.9262 - val_loss: 0.1944
# Epoch 50/50
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9206 - loss: 0.2135 - val_accuracy: 0.9261 - val_loss: 0.1981

# %%
from tensorflow.keras.callbacks import EarlyStopping

Early_Stopping_callback=EarlyStopping(monitor='val_loss',patience=10,restore_best_weights=True)
history = model.fit(
    x_train,y_train,
    validation_data=(x_test,y_test),
    epochs=100,
    callbacks=[Early_Stopping_callback]
    )
# Out:
# Epoch 1/100
# 881/881 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.