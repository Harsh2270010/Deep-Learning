# %%
import numpy as np
import pandas as pd
import cv2
import PIL.Image as Image
import os
import matplotlib.pyplot as plt
import pathlib
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Conv2D , MaxPooling2D,Flatten
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
print("all set !")
# Out:
# all set !

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\verma\\OneDrive\\Desktop\\Deep-Learning\\opencv'

# %%
os.path.join(current_dir, "data")
# Out:
# 'c:\\Users\\verma\\OneDrive\\Desktop\\Deep-Learning\\opencv\\data'

# %%
"dog images :" , len(os.path.join(current_dir,"data","dogs"))
"cat images :" , len(os.path.join(current_dir,"data","cats"))
# Out:
# ('cat images :', 62)

# %%
image_path = os.path.join(current_dir ,"data","img")
image_path
# Out:
# 'c:\\Users\\verma\\OneDrive\\Desktop\\Deep-Learning\\opencv\\data\\img'

# %%
os.listdir(image_path)
# Out:
# ['cats', 'dogs']

# %%
path_dict = {"cats":[],"dogs":[]}
for dir in os.listdir(image_path):
    directory_path = os.path.join(image_path, dir)
    for images in os.listdir(directory_path):
        path_dict[dir].append(os.path.join(directory_path,images))

# %%
cat_images_demo=Image.open(path_dict["cats"][4])
cat_images_demo
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=459x495>

# %%
dog_images_demo=Image.open(path_dict["dogs"][8])
dog_images_demo
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x758>
